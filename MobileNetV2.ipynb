# %% [markdown]
# ## Pretrained MobileNetV2 model

# %%
# 3 channel image
# no bounding box + pretrained data
# %reset -f
import torch
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
def get_data(images):
    train_images = images
    temp_images = []
    
    for i in range(len(train_images)):
        img_idx = i
        temp_images.append([])
        temp_images[i] = cv2.resize(train_images[img_idx],(64,64))
        temp_images[i] = cv2.cvtColor(temp_images[i],cv2.COLOR_GRAY2BGR)
        
        image = np.ascontiguousarray(train_images[img_idx], dtype=np.uint8)

        ret, threshed_img = cv2.threshold(image,
                        240, 255, cv2.THRESH_BINARY)
        img, contours, her = cv2.findContours(threshed_img, cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
        
        largest_dim = {"x":0, "y":0, "w":0, "h":0}
        largest_area = 0
        for num in contours:
            x,y,w,h = cv2.boundingRect(num)
            
            temp = 0
            
            if w > h:
                temp=w
            else:
                temp=h
                
            if temp*temp > largest_area:
                largest_area = temp*temp
                largest_dim["x"] = x
                largest_dim["y"] = y
                largest_dim["w"] = w
                largest_dim["h"] = h
        

        b = threshed_img[largest_dim["y"]:largest_dim["y"]+largest_dim["h"],largest_dim["x"]:largest_dim["x"]+largest_dim["w"]]
    
    temp_images = np.asarray(temp_images, dtype=np.float32)
    
    
    return temp_images
  
def split_data(train_size, valid_size, test_size):
    images = pd.read_pickle('gdrive/My Drive/proj3_kera/train/train_images.pkl')
    labels = pd.read_csv('gdrive/My Drive/proj3_kera/train/train_labels.csv')
    return (images[:train_size], images[train_size:train_size+valid_size],0),(labels[:train_size], labels[train_size:train_size+valid_size],0)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.optimizers import Adam, SGD
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.layers.advanced_activations import LeakyReLU 
from keras.preprocessing.image import ImageDataGenerator

np.random.seed(25)




(X_train, X_test, final_images), (train_labels_new, test_labels_new, final_labels)=split_data(38000, 2000, 0)

X_train = get_data(X_train)
X_test = get_data(X_test)

y_train = np.array(train_labels_new["Category"].tolist(), dtype="uint8")
y_test = np.array(test_labels_new["Category"].tolist(), dtype="uint8")


print("X_train original shape", X_train.shape)
print("y_train original shape", y_train.shape)
print("X_test original shape", X_test.shape)
print("y_test original shape", y_test.shape)

# input image dimensions
img_rows, img_cols = 71, 71

# the data, split between train and test sets
X_train = X_train.reshape(X_train.shape[0], 64, 64, 3)
X_test = X_test.reshape(X_test.shape[0], 64, 64, 3)

X_train/=255
X_test/=255

X_train.shape

number_of_classes = 10


Y_train = np_utils.to_categorical(y_train, number_of_classes)
Y_test = np_utils.to_categorical(y_test, number_of_classes)

# Build MobileNetV2 model

from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.applications.xception import Xception

from keras.applications.densenet import DenseNet201
from keras.applications.inception_v3 import InceptionV3
from keras.applications.mobilenet_v2 import MobileNetV2


model = MobileNetV2(include_top=True, weights=None, input_tensor=None, input_shape=(64,64,3), pooling="avg", classes=10)


model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
gen = ImageDataGenerator(rotation_range=8, width_shift_range=0.08, shear_range=0.3,
                         height_shift_range=0.08, zoom_range=0.08)
gen.fit(X_train)

train_generator = gen.flow(X_train, Y_train, batch_size=64)
test_generator = gen.flow(X_test, Y_test, batch_size=64)


#check point
from keras.callbacks import ModelCheckpoint
filepath="gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-{epoch:02d}-{val_acc:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, mode='auto', period=1)
callbacks_list = [checkpoint]

#run model
history_MobileNetV2_64 = model.fit_generator(train_generator, steps_per_epoch=38000//64, epochs=100,validation_data=test_generator, validation_steps=2000//64,callbacks=callbacks_list)


score = model.evaluate(gen.standardize(X_test), Y_test)
print()
print('Test accuracy: ', score[1])
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# X_train original shape (38000, 64, 64, 3)
# y_train original shape (38000,)
# X_test original shape (2000, 64, 64, 3)
# y_test original shape (2000,)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 593/593 [==============================] - 172s 290ms/step - loss: 2.2582 - acc: 0.1602 - val_loss: 10.5435 - val_acc: 0.0902
#
# Epoch 00001: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-01-0.0902.hdf5
# Epoch 2/100
# 593/593 [==============================] - 180s 303ms/step - loss: 1.3903 - acc: 0.5188 - val_loss: 9.0159 - val_acc: 0.1338
#
# Epoch 00002: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-02-0.1338.hdf5
# Epoch 3/100
# 593/593 [==============================] - 178s 300ms/step - loss: 0.6452 - acc: 0.8032 - val_loss: 5.5398 - val_acc: 0.3192
#
# Epoch 00003: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-03-0.3192.hdf5
# Epoch 4/100
# 593/593 [==============================] - 179s 302ms/step - loss: 0.4555 - acc: 0.8649 - val_loss: 9.9387 - val_acc: 0.1849
#
# Epoch 00004: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-04-0.1849.hdf5
# Epoch 5/100
# 593/593 [==============================] - 178s 301ms/step - loss: 0.3660 - acc: 0.8897 - val_loss: 4.1781 - val_acc: 0.5362
#
# Epoch 00005: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-05-0.5362.hdf5
# Epoch 6/100
# 593/593 [==============================] - 179s 301ms/step - loss: 0.3336 - acc: 0.9009 - val_loss: 4.6989 - val_acc: 0.5067
#
# Epoch 00006: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-06-0.5067.hdf5
# Epoch 7/100
# 593/593 [==============================] - 176s 297ms/step - loss: 0.2989 - acc: 0.9102 - val_loss: 3.5887 - val_acc: 0.5630
#
# Epoch 00007: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-07-0.5630.hdf5
# Epoch 8/100
# 593/593 [==============================] - 180s 303ms/step - loss: 0.2785 - acc: 0.9179 - val_loss: 4.4065 - val_acc: 0.5403
#
# Epoch 00008: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-08-0.5403.hdf5
# Epoch 9/100
# 593/593 [==============================] - 177s 299ms/step - loss: 0.2593 - acc: 0.9205 - val_loss: 2.4344 - val_acc: 0.6968
#
# Epoch 00009: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-09-0.6968.hdf5
# Epoch 10/100
# 593/593 [==============================] - 179s 303ms/step - loss: 0.2441 - acc: 0.9267 - val_loss: 5.4608 - val_acc: 0.4241
#
# Epoch 00010: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-10-0.4241.hdf5
# Epoch 11/100
# 593/593 [==============================] - 177s 298ms/step - loss: 0.2318 - acc: 0.9291 - val_loss: 4.3138 - val_acc: 0.4959
#
# Epoch 00011: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-11-0.4959.hdf5
# Epoch 12/100
# 593/593 [==============================] - 178s 300ms/step - loss: 0.2133 - acc: 0.9355 - val_loss: 2.9427 - val_acc: 0.5971
#
# Epoch 00012: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-12-0.5971.hdf5
# Epoch 13/100
# 593/593 [==============================] - 175s 296ms/step - loss: 0.2057 - acc: 0.9377 - val_loss: 1.1536 - val_acc: 0.8228
#
# Epoch 00013: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-13-0.8228.hdf5
# Epoch 14/100
# 593/593 [==============================] - 178s 300ms/step - loss: 0.2043 - acc: 0.9390 - val_loss: 5.1508 - val_acc: 0.4411
#
# Epoch 00014: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-14-0.4411.hdf5
# Epoch 15/100
# 593/593 [==============================] - 176s 297ms/step - loss: 0.1888 - acc: 0.9440 - val_loss: 4.4591 - val_acc: 0.4566
#
# Epoch 00015: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-15-0.4566.hdf5
# Epoch 16/100
# 593/593 [==============================] - 178s 301ms/step - loss: 0.1857 - acc: 0.9429 - val_loss: 2.6664 - val_acc: 0.5873
#
# Epoch 00016: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-16-0.5873.hdf5
# Epoch 17/100
# 593/593 [==============================] - 177s 298ms/step - loss: 0.1744 - acc: 0.9462 - val_loss: 0.9781 - val_acc: 0.8079
#
# Epoch 00017: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-17-0.8079.hdf5
# Epoch 18/100
# 593/593 [==============================] - 177s 299ms/step - loss: 0.1688 - acc: 0.9479 - val_loss: 1.2386 - val_acc: 0.7841
#
# Epoch 00018: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-18-0.7841.hdf5
# Epoch 19/100
# 593/593 [==============================] - 173s 292ms/step - loss: 0.1713 - acc: 0.9481 - val_loss: 0.7619 - val_acc: 0.8414
#
# Epoch 00019: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-19-0.8414.hdf5
# Epoch 20/100
# 593/593 [==============================] - 176s 297ms/step - loss: 0.1582 - acc: 0.9525 - val_loss: 0.7123 - val_acc: 0.8378
#
# Epoch 00020: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-20-0.8378.hdf5
# Epoch 21/100
# 593/593 [==============================] - 176s 296ms/step - loss: 0.1539 - acc: 0.9531 - val_loss: 1.0883 - val_acc: 0.7707
#
# Epoch 00021: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-21-0.7707.hdf5
# Epoch 22/100
# 593/593 [==============================] - 177s 299ms/step - loss: 0.1507 - acc: 0.9527 - val_loss: 1.1201 - val_acc: 0.7624
#
# Epoch 00022: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-22-0.7624.hdf5
# Epoch 23/100
# 593/593 [==============================] - 175s 296ms/step - loss: 0.1451 - acc: 0.9561 - val_loss: 0.4559 - val_acc: 0.8843
#
# Epoch 00023: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-23-0.8843.hdf5
# Epoch 24/100
# 593/593 [==============================] - 178s 300ms/step - loss: 0.1456 - acc: 0.9555 - val_loss: 0.7180 - val_acc: 0.8316
#
# Epoch 00024: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-24-0.8316.hdf5
# Epoch 25/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.1354 - acc: 0.9575 - val_loss: 0.3109 - val_acc: 0.9220
#
# Epoch 00025: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-25-0.9220.hdf5
# Epoch 26/100
# 593/593 [==============================] - 177s 298ms/step - loss: 0.1338 - acc: 0.9581 - val_loss: 0.4031 - val_acc: 0.9013
#
# Epoch 00026: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-26-0.9013.hdf5
# Epoch 27/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.1323 - acc: 0.9590 - val_loss: 0.4798 - val_acc: 0.8900
#
# Epoch 00027: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-27-0.8900.hdf5
# Epoch 28/100
# 593/593 [==============================] - 177s 298ms/step - loss: 0.1254 - acc: 0.9612 - val_loss: 0.4895 - val_acc: 0.8802
#
# Epoch 00028: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-28-0.8802.hdf5
# Epoch 29/100
# 593/593 [==============================] - 175s 294ms/step - loss: 0.1231 - acc: 0.9615 - val_loss: 0.6565 - val_acc: 0.8301
#
# Epoch 00029: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-29-0.8301.hdf5
# Epoch 30/100
# 593/593 [==============================] - 177s 299ms/step - loss: 0.1209 - acc: 0.9620 - val_loss: 0.3740 - val_acc: 0.9044
#
# Epoch 00030: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-30-0.9044.hdf5
# Epoch 31/100
# 593/593 [==============================] - 173s 292ms/step - loss: 0.1179 - acc: 0.9620 - val_loss: 0.4662 - val_acc: 0.8693
#
# Epoch 00031: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-31-0.8693.hdf5
# Epoch 32/100
# 593/593 [==============================] - 176s 297ms/step - loss: 0.1115 - acc: 0.9650 - val_loss: 0.3091 - val_acc: 0.9210
#
# Epoch 00032: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-32-0.9210.hdf5
# Epoch 33/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.1125 - acc: 0.9646 - val_loss: 0.9751 - val_acc: 0.7893
#
# Epoch 00033: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-33-0.7893.hdf5
# Epoch 34/100
# 593/593 [==============================] - 177s 299ms/step - loss: 0.1093 - acc: 0.9647 - val_loss: 0.3410 - val_acc: 0.9137
#
# Epoch 00034: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-34-0.9137.hdf5
# Epoch 35/100
# 593/593 [==============================] - 174s 293ms/step - loss: 0.1141 - acc: 0.9646 - val_loss: 0.2291 - val_acc: 0.9329
#
# Epoch 00035: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-35-0.9329.hdf5
# Epoch 36/100
# 593/593 [==============================] - 177s 298ms/step - loss: 0.1045 - acc: 0.9668 - val_loss: 0.4138 - val_acc: 0.8915
#
# Epoch 00036: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-36-0.8915.hdf5
# Epoch 37/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.1037 - acc: 0.9676 - val_loss: 0.2427 - val_acc: 0.9354
#
# Epoch 00037: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-37-0.9354.hdf5
# Epoch 38/100
# 593/593 [==============================] - 176s 297ms/step - loss: 0.1010 - acc: 0.9676 - val_loss: 0.3214 - val_acc: 0.9205
#
# Epoch 00038: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-38-0.9205.hdf5
# Epoch 39/100
# 593/593 [==============================] - 173s 291ms/step - loss: 0.1003 - acc: 0.9680 - val_loss: 0.2866 - val_acc: 0.9277
#
# Epoch 00039: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-39-0.9277.hdf5
# Epoch 40/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.1043 - acc: 0.9669 - val_loss: 0.2797 - val_acc: 0.9318
#
# Epoch 00040: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-40-0.9318.hdf5
# Epoch 41/100
# 593/593 [==============================] - 173s 292ms/step - loss: 0.0931 - acc: 0.9695 - val_loss: 0.3180 - val_acc: 0.9251
#
# Epoch 00041: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-41-0.9251.hdf5
# Epoch 42/100
# 593/593 [==============================] - 177s 299ms/step - loss: 0.0959 - acc: 0.9700 - val_loss: 0.1558 - val_acc: 0.9535
#
# Epoch 00042: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-42-0.9535.hdf5
# Epoch 43/100
# 593/593 [==============================] - 173s 292ms/step - loss: 0.0874 - acc: 0.9716 - val_loss: 0.3486 - val_acc: 0.9075
#
# Epoch 00043: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-43-0.9075.hdf5
# Epoch 44/100
# 593/593 [==============================] - 174s 294ms/step - loss: 0.0922 - acc: 0.9705 - val_loss: 0.1885 - val_acc: 0.9421
#
# Epoch 00044: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-44-0.9421.hdf5
# Epoch 45/100
# 593/593 [==============================] - 172s 290ms/step - loss: 0.0853 - acc: 0.9718 - val_loss: 0.3358 - val_acc: 0.9199
#
# Epoch 00045: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-45-0.9199.hdf5
# Epoch 46/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.0868 - acc: 0.9718 - val_loss: 0.2407 - val_acc: 0.9365
#
# Epoch 00046: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-46-0.9365.hdf5
# Epoch 47/100
# 593/593 [==============================] - 174s 294ms/step - loss: 0.0868 - acc: 0.9725 - val_loss: 0.1506 - val_acc: 0.9540
#
# Epoch 00047: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-47-0.9540.hdf5
# Epoch 48/100
# 593/593 [==============================] - 175s 296ms/step - loss: 0.0849 - acc: 0.9728 - val_loss: 0.3192 - val_acc: 0.9112
#
# Epoch 00048: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-48-0.9112.hdf5
# Epoch 49/100
# 593/593 [==============================] - 174s 294ms/step - loss: 0.0819 - acc: 0.9738 - val_loss: 0.2231 - val_acc: 0.9354
#
# Epoch 00049: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-49-0.9354.hdf5
# Epoch 50/100
# 593/593 [==============================] - 175s 296ms/step - loss: 0.0817 - acc: 0.9734 - val_loss: 0.3477 - val_acc: 0.9029
#
# Epoch 00050: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-50-0.9029.hdf5
# Epoch 51/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.0810 - acc: 0.9735 - val_loss: 0.2022 - val_acc: 0.9447
#
# Epoch 00051: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-51-0.9447.hdf5
# Epoch 52/100
# 593/593 [==============================] - 175s 296ms/step - loss: 0.0773 - acc: 0.9747 - val_loss: 0.2356 - val_acc: 0.9360
#
# Epoch 00052: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-52-0.9360.hdf5
# Epoch 53/100
# 593/593 [==============================] - 173s 291ms/step - loss: 0.0779 - acc: 0.9746 - val_loss: 0.2113 - val_acc: 0.9370
#
# Epoch 00053: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-53-0.9370.hdf5
# Epoch 54/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.0781 - acc: 0.9742 - val_loss: 0.3173 - val_acc: 0.9168
#
# Epoch 00054: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-54-0.9168.hdf5
# Epoch 55/100
# 593/593 [==============================] - 174s 293ms/step - loss: 0.0768 - acc: 0.9752 - val_loss: 0.3043 - val_acc: 0.9194
#
# Epoch 00055: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-55-0.9194.hdf5
# Epoch 56/100
# 593/593 [==============================] - 177s 298ms/step - loss: 0.0762 - acc: 0.9750 - val_loss: 0.1745 - val_acc: 0.9545
#
# Epoch 00056: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-56-0.9545.hdf5
# Epoch 57/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.0710 - acc: 0.9770 - val_loss: 0.2159 - val_acc: 0.9478
#
# Epoch 00057: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-57-0.9478.hdf5
# Epoch 58/100
# 593/593 [==============================] - 177s 299ms/step - loss: 0.0705 - acc: 0.9765 - val_loss: 0.2190 - val_acc: 0.9401
#
# Epoch 00058: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-58-0.9401.hdf5
# Epoch 59/100
# 593/593 [==============================] - 173s 292ms/step - loss: 0.0745 - acc: 0.9757 - val_loss: 0.3535 - val_acc: 0.9039
#
# Epoch 00059: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-59-0.9039.hdf5
# Epoch 60/100
# 593/593 [==============================] - 174s 293ms/step - loss: 0.0704 - acc: 0.9774 - val_loss: 0.2771 - val_acc: 0.9292
#
# Epoch 00060: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-60-0.9292.hdf5
# Epoch 61/100
# 593/593 [==============================] - 171s 288ms/step - loss: 0.0708 - acc: 0.9774 - val_loss: 0.2238 - val_acc: 0.9380
#
# Epoch 00061: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-61-0.9380.hdf5
# Epoch 62/100
# 593/593 [==============================] - 173s 292ms/step - loss: 0.0649 - acc: 0.9781 - val_loss: 0.2391 - val_acc: 0.9427
#
# Epoch 00062: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-62-0.9427.hdf5
# Epoch 63/100
# 593/593 [==============================] - 171s 289ms/step - loss: 0.0644 - acc: 0.9781 - val_loss: 0.1916 - val_acc: 0.9489
#
# Epoch 00063: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-63-0.9489.hdf5
# Epoch 64/100
# 593/593 [==============================] - 175s 295ms/step - loss: 0.0654 - acc: 0.9780 - val_loss: 0.3140 - val_acc: 0.9184
#
# Epoch 00064: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-64-0.9184.hdf5
# Epoch 65/100
# 593/593 [==============================] - 171s 288ms/step - loss: 0.0654 - acc: 0.9778 - val_loss: 0.2241 - val_acc: 0.9405
#
# Epoch 00065: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-65-0.9405.hdf5
# Epoch 66/100
# 593/593 [==============================] - 172s 291ms/step - loss: 0.0631 - acc: 0.9787 - val_loss: 0.2228 - val_acc: 0.9375
#
# Epoch 00066: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-66-0.9375.hdf5
# Epoch 67/100
# 593/593 [==============================] - 173s 292ms/step - loss: 0.0650 - acc: 0.9789 - val_loss: 0.3054 - val_acc: 0.9287
#
# Epoch 00067: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-67-0.9287.hdf5
# Epoch 68/100
# 593/593 [==============================] - 174s 293ms/step - loss: 0.0635 - acc: 0.9790 - val_loss: 0.2698 - val_acc: 0.9298
#
# Epoch 00068: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-68-0.9298.hdf5
# Epoch 69/100
# 593/593 [==============================] - 172s 290ms/step - loss: 0.0620 - acc: 0.9784 - val_loss: 0.2224 - val_acc: 0.9416
#
# Epoch 00069: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-69-0.9416.hdf5
# Epoch 70/100
# 593/593 [==============================] - 172s 290ms/step - loss: 0.0611 - acc: 0.9801 - val_loss: 0.1757 - val_acc: 0.9592
#
# Epoch 00070: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-70-0.9592.hdf5
# Epoch 71/100
# 593/593 [==============================] - 171s 289ms/step - loss: 0.0582 - acc: 0.9808 - val_loss: 0.1772 - val_acc: 0.9489
#
# Epoch 00071: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-71-0.9489.hdf5
# Epoch 72/100
# 593/593 [==============================] - 175s 294ms/step - loss: 0.0645 - acc: 0.9788 - val_loss: 0.1935 - val_acc: 0.9437
#
# Epoch 00072: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-72-0.9437.hdf5
# Epoch 73/100
# 593/593 [==============================] - 171s 289ms/step - loss: 0.0562 - acc: 0.9810 - val_loss: 0.1956 - val_acc: 0.9468
#
# Epoch 00073: saving model to gdrive/My Drive/proj3_kera/model_proj_net/weights-improvement-73-0.9468.hdf5
# Epoch 74/100
#  89/593 [===>..........................] - ETA: 1:31 - loss: 0.0604 - acc: 0.9810
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b6512f168ec7> in <module>()
#     206
#     207 #run model
# --> 208 history_MobileNetV2_64 = model.fit_generator(train_generator, steps_per_epoch=38000//64, epochs=100,validation_data=test_generator, validation_steps=2000//64,callbacks=callbacks_list)
#     209
#     210
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
